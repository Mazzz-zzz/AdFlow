# %%
import pandas as pd
from openai import OpenAI
from qdrant_client import QdrantClient
from qdrant_client.http import models
import os
from tqdm import tqdm
from dotenv import load_dotenv  # Add this import

# Load environment variables from .env file
load_dotenv()

# Get environment variables
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
QDRANT_API_KEY = os.getenv('QDRANT_API_KEY')
QDRANT_URL = 'https://00c28ff2-8890-425a-84d0-6e06dcbcfc11.us-east4-0.gcp.cloud.qdrant.io'


# Validate environment variables
if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY not found in environment variables")
if not QDRANT_API_KEY:
    raise ValueError("QDRANT_API_KEY not found in environment variables")

# Initialize OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)


# Initialize Qdrant client
qdrant_client = QdrantClient(
     url=QDRANT_URL,
    api_key=QDRANT_API_KEY,
)

# Function to create embedding for text
def get_embedding(text):
    response = client.embeddings.create(
        input=text,
        model="text-embedding-3-small"  # or "text-embedding-ada-002" for older version
    )
    return response.data[0].embedding

# Function to prepare patient data for embedding
def prepare_patient_text(row):
    # Customize this function based on your dataset columns
    return f"""
    Patient ID: {row['patient_uid']}
    [Add relevant patient fields here]
    """

# Read your dataset
df = pd.read_csv('dataset1/allergies.csv')  # Update with your dataset path

# Create collection in Qdrant
collection_name = "patients"
qdrant_client.recreate_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(
        size=1536,  # 1536 for text-embedding-3-small, 1024 for ada-002
        distance=models.Distance.COSINE
    )
)

# Process each patient and upload embeddings
batch_size = 100  # Adjust based on your needs
for i in tqdm(range(0, len(df), batch_size)):
    batch = df.iloc[i:i+batch_size]

    # Prepare batch data
    points = []
    for _, row in batch.iterrows():
        # Prepare text for embedding
        text = prepare_patient_text(row)

        # Get embedding
        embedding = get_embedding(text)

        # Create point
        point = models.PointStruct(
            id=row['patient_uid'],  # Using patient_uid as the point ID
            vector=embedding,
            payload={
                'patient_uid': row['patient_uid'],
                # Add other relevant fields you want to store
            }
        )
        points.append(point)

    # Upload batch to Qdrant
    qdrant_client.upsert(
        collection_name=collection_name,
        points=points
    )

print("Upload complete!")
# Out:
# /var/folders/h_/0r3j9b0141ldmbypkym676zw0000gn/T/ipykernel_30440/3986111329.py:29: UserWarning: Failed to obtain server version. Unable to check client-server compatibility. Set check_version=False to skip version check.
#   qdrant_client = QdrantClient(
# /var/folders/h_/0r3j9b0141ldmbypkym676zw0000gn/T/ipykernel_30440/3986111329.py:55: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   qdrant_client.recreate_collection(
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[7], line 55
#      53 # Create collection in Qdrant
#      54 collection_name = "patients"
# ---> 55 qdrant_client.recreate_collection(
#      56     collection_name=collection_name,
#      57     vectors_config=models.VectorParams(
#      58         size=1536,  # 1536 for text-embedding-3-small, 1024 for ada-002
#      59         distance=models.Distance.COSINE
#      60     )
#      61 )
#      63 # Process each patient and upload embeddings
#      64 batch_size = 100  # Adjust based on your needs
#
# File ~/Documents/MediHack/medihack-env/lib/python3.13/site-packages/qdrant_client/qdrant_client.py:2407, in QdrantClient.recreate_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2398 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
#    2400 warnings.warn(
#    2401     "`recreate_collection` method is deprecated and will be removed in the future."
#    2402     " Use `collection_exists` to check collection existence and `create_collection` instead.",
#    2403     DeprecationWarning,
#    2404     stacklevel=2,
#    2405 )
# -> 2407 return self._client.recreate_collection(
#    2408     collection_name=collection_name,
#    2409     vectors_config=vectors_config,
#    2410     shard_number=shard_number,
#    2411     sharding_method=sharding_method,
#    2412     replication_factor=replication_factor,
#    2413     write_consistency_factor=write_consistency_factor,
#    2414     on_disk_payload=on_disk_payload,
#    2415     hnsw_config=hnsw_config,
#    2416     optimizers_config=optimizers_config,
#    2417     wal_config=wal_config,
#    2418     quantization_config=quantization_config,
#    2419     init_from=init_from,
#    2420     timeout=timeout,
#    2421     sparse_vectors_config=sparse_vectors_config,
#    2422     strict_mode_config=strict_mode_config,
#    2423     **kwargs,
#    2424 )
#
# File ~/Documents/MediHack/medihack-env/lib/python3.13/site-packages/qdrant_client/qdrant_remote.py:2838, in QdrantRemote.recreate_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2819 def recreate_collection(
#    2820     self,
#    2821     collection_name: str,
#    (...)
#    2836     **kwargs: Any,
#    2837 ) -> bool:
# -> 2838     self.delete_collection(collection_name, timeout=timeout)
#    2840     return self.create_collection(
#    2841         collection_name=collection_name,
#    2842         vectors_config=vectors_config,
#    (...)
#    2855         strict_mode_config=strict_mode_config,
#    2856     )
#
# File ~/Documents/MediHack/medihack-env/lib/python3.13/site-packages/qdrant_client/qdrant_remote.py:2694, in QdrantRemote.delete_collection(self, collection_name, timeout, **kwargs)
#    2688 if self._prefer_grpc:
#    2689     return self.grpc_collections.Delete(
#    2690         grpc.DeleteCollection(collection_name=collection_name, timeout=timeout),
#    2691         timeout=timeout if timeout is not None else self._timeout,
#    2692     ).result
# -> 2694 result: Optional[bool] = self.http.collections_api.delete_collection(
#    2695     collection_name, timeout=timeout
#    2696 ).result
#    2697 assert result is not None, "Delete collection returned None"
#    2698 return result
#
# File ~/Documents/MediHack/medihack-env/lib/python3.13/site-packages/qdrant_client/http/api/collections_api.py:308, in SyncCollectionsApi.delete_collection(self, collection_name, timeout)
#     300 def delete_collection(
#     301     self,
#     302     collection_name: str,
#     303     timeout: int = None,
#     304 ) -> m.InlineResponse200:
#     305     """
#     306     Drop collection and all associated data
#     307     """
# --> 308     return self._build_for_delete_collection(
#     309         collection_name=collection_name,
#     310         timeout=timeout,
#     311     )
#
# File ~/Documents/MediHack/medihack-env/lib/python3.13/site-packages/qdrant_client/http/api/collections_api.py:123, in _CollectionsApi._build_for_delete_collection(self, collection_name, timeout)
#     120     query_params["timeout"] = str(timeout)
#     122 headers = {}
# --> 123 return self.api_client.request(
#     124     type_=m.InlineResponse200,
#     125     method="DELETE",
#     126     url="/collections/{collection_name}",
#     127     headers=headers if headers else None,
#     128     path_params=path_params,
#     129     params=query_params,
#     130 )
#
# File ~/Documents/MediHack/medihack-env/lib/python3.13/site-packages/qdrant_client/http/api_client.py:89, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      87     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      88 request = self._client.build_request(method, url, **kwargs)
# ---> 89 return self.send(request, type_)
#
# File ~/Documents/MediHack/medihack-env/lib/python3.13/site-packages/qdrant_client/http/api_client.py:112, in ApiClient.send(self, request, type_)
#     110     except ValidationError as e:
#     111         raise ResponseHandlingException(e)
# --> 112 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 403 (Forbidden)
# Raw response content:
# b'{"error":"forbidden"}'
